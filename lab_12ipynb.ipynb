# %% [markdown]
# <a href="https://colab.research.google.com/github/ParushiSrivastava/PARUSHI.23FE10CSE00380/blob/main/lab_12ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

from transformers import pipeline

# %%
generator = pipeline(
    "text-generation",
    model="gpt2"
)

# %%
prompt1 = "Machine learning is"

output1 = generator(
    prompt1,
    max_length=40,
    num_return_sequences=1
)

print("Prompt 1 Output:\n")
print(output1[0]['generated_text'])

# %%
prompt2 = "Generative AI can be used for"

output2 = generator(
    prompt2,
    max_length=40
)

print("\nPrompt 2 Output:\n")
print(output2[0]['generated_text'])

# %%
prompt3 = "The future of artificial intelligence is"

output3 = generator(
    prompt3,
    max_length=40
)

print("\nPrompt 3 Output:\n")
print(output3[0]['generated_text'])
